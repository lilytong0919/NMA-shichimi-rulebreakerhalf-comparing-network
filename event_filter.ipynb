# %%
import sys
# !{sys.executable} -m pip install -U pip --quiet
# !{sys.executable} -m pip install motornet --quiet
# !{sys.executable} -m pip install git+https://github.com/OlivierCodol/MotorNet.git --quiet
# !pip install --no-cache-dir --force-reinstall --no-deps \
    git+https://github.com/lilytong0919/NMA-shichimi-rulebreakerhalf-comparing-network.git
# !pip install pynapple --quiet
# !pip install dandi --quiet
# !python3 -m pip install pynapple --quiet
from google.colab import drive
import monkeypaw.io as mpio
import pandas as pd
from dandi.download import download as dandi_download
import os
import pynapple as nap
import numpy as np
import matplotlib.pyplot as plt

# 2. Mount Google Drive for persistent storage
drive.mount('/content/drive')

# 3. Define a dedicated folder inside your Google Drive
drive_data_dir = "/content/drive/MyDrive/Dandi_Datasets/data"
os.makedirs(drive_data_dir, exist_ok=True)

filenames = [
    "sub-Dataset-3-Animals-1-to-4",
    "sub-Dataset-4-Animal-2-sess-1-to-7",
    "sub-Dataset-4-Animal-2-sess-8-to-12",
    "sub-Dataset-4-Animal-3-sess-1-to-6",
    "sub-Dataset-4-Animal-3-sess-7-to-11",
    "sub-Dataset-5-Animal-1",
    "sub-Dataset-5-Animals-2-ses-1-to-19",
    "sub-Dataset-5-Animals-2-ses-20-to-39",
    "sub-Dataset-5-Animals-2-ses-40-to-51",
    "sub-Dataset-5-Animals-3&4"
]

url_base = 'https://dandiarchive.org/dandiset/001057/draft/files?location='

# 4. Check if the directory already has files to avoid starting the dandi client
if os.path.exists(drive_data_dir) and len(os.listdir(drive_data_dir)) >= len(filenames):
    print("✨ All files are already saved in Google Drive! Skipping download loop.")
else:
    print("⏳ Files missing. Running DANDI download loop straight to Google Drive...")
    for filename in filenames:
        url = url_base + filename
        # Downloads directly into your persistent Drive folder
        dandi_download(
            [url],
            output_dir=drive_data_dir,
            existing="skip"
        )
    print("✅ Download complete and saved to Google Drive.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 22.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for motornet (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting git+https://github.com/lilytong0919/NMA-shichimi-rulebreakerhalf-comparing-network.git
#   Cloning https://github.com/lilytong0919/NMA-shichimi-rulebreakerhalf-comparing-network.git to /tmp/pip-req-build-xxvfpo1z
#   Running command git clone --filter=blob:none --quiet https://github.com/lilytong0919/NMA-shichimi-rulebreakerhalf-comparing-network.git /tmp/pip-req-build-xxvfpo1z
#   Resolved https://github.com/lilytong0919/NMA-shichimi-rulebreakerhalf-comparing-network.git to commit a4f92b681a7194e55b86e5f7f0afdb7bdbb267db
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: monkeypaw
#   Building wheel for monkeypaw (pyproject.toml) ... done
#   Created wheel for monkeypaw: filename=monkeypaw-0.1.0-py3-none-any.whl size=7527 sha256=fc36f637696b6434b80e8aa2ee9a82eaf12f1009a0545f97549cc4848e374300
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ql9vdza9/wheels/c5/4d/e0/f4cdde16d1079b6e82b4e94fb243e7e447475b8f6c6ad15d9c
# Successfully built monkeypaw
# Installing collected packages: monkeypaw
# Successfully installed monkeypaw-0.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# monkeypaw 0.1.0 requires rsatoolbox, which is not installed.
# Mounted at /content/drive
# ⏳ Files missing. Running DANDI download loop straight to Google Drive...
# PATH                                                          SIZE    DONE           DONE% CHECKSUM STATUS          MESSAGE
# sub-Dataset-3-Animals-1-to-4/sub-Dataset-3-Animals-1-to-4.nwb 80.5 MB 80.5 MB         100%    ok    done
# Summary:                                                      80.5 MB 80.5 MB                       1 done
#                                                                       100.00%
# PATH                                                                      SIZE     DONE            DONE% CHECKSUM STATUS          MESSAGE
# sub-Dataset-4-Animal-2-sess-1-to-7/sub-Dataset-4-Animal-2-sess-1-to-7.nwb 379.5 MB 379.5 MB         100%    ok    done
# Summary:                                                                  379.5 MB 379.5 MB                       1 done
#                                                                                    100.00%
# PATH                                                                        SIZE     DONE            DONE% CHECKSUM STATUS          MESSAGE
# sub-Dataset-4-Animal-2-sess-8-to-12/sub-Dataset-4-Animal-2-sess-8-to-12.nwb 308.0 MB 308.0 MB         100%    ok    done
# Summary:                                                                    308.0 MB 308.0 MB                       1 done
#                                                                                      100.00%
# PATH                                                                      SIZE     DONE            DONE% CHECKSUM STATUS          MESSAGE
# sub-Dataset-4-Animal-3-sess-1-to-6/sub-Dataset-4-Animal-3-sess-1-to-6.nwb 441.7 MB 441.7 MB         100%    ok    done
# Summary:                                                                  441.7 MB 441.7 MB                       1 done
#                                                                                    100.00%
# PATH                                                                        SIZE     DONE            DONE% CHECKSUM STATUS          MESSAGE
# sub-Dataset-4-Animal-3-sess-7-to-11/sub-Dataset-4-Animal-3-sess-7-to-11.nwb 340.4 MB 340.4 MB         100%    ok    done
# Summary:                                                                    340.4 MB 340.4 MB                       1 done
#                                                                                      100.00%
# PATH                                              SIZE     DONE            DONE% CHECKSUM STATUS          MESSAGE
# sub-Dataset-5-Animal-1/sub-Dataset-5-Animal-1.nwb 340.3 MB 340.3 MB         100%    ok    done
# Summary:                                          340.3 MB 340.3 MB                       1 done
#                                                            100.00%
# PATH                                                                        SIZE     DONE            DONE% CHECKSUM STATUS          MESSAGE
# sub-Dataset-5-Animals-2-ses-1-to-19/sub-Dataset-5-Animals-2-ses-1-to-19.nwb 249.3 MB 249.3 MB         100%    ok    done
# Summary:                                                                    249.3 MB 249.3 MB                       1 done
#                                                                                      100.00%
# PATH                                                                          SIZE     DONE            DONE% CHECKSUM STATUS          MESSAGE
# sub-Dataset-5-Animals-2-ses-20-to-39/sub-Dataset-5-Animals-2-ses-20-to-39.nwb 164.1 MB 164.1 MB         100%    ok    done
# Summary:                                                                      164.1 MB 164.1 MB                       1 done
#                                                                                        100.00%
# PATH                                                                          SIZE     DONE            DONE% CHECKSUM STATUS          MESSAGE
# sub-Dataset-5-Animals-2-ses-40-to-51/sub-Dataset-5-Animals-2-ses-40-to-51.nwb 131.0 MB 131.0 MB         100%    ok    done
# Summary:                                                                      131.0 MB 131.0 MB                       1 done
#                                                                                        100.00%
# PATH                                                    SIZE    DONE           DONE% CHECKSUM STATUS          MESSAGE
# sub-Dataset-5-Animals-3&4/sub-Dataset-5-Animals-3&4.nwb 65.6 MB 65.6 MB         100%    ok    done
# Summary:                                                65.6 MB 65.6 MB                       1 done
#                                                                 100.00%
# ✅ Download complete and saved to Google Drive.

# %%
peth = all_peth['peth_go']

indices = get_index_from_info(info.as_dataframe(), by = ["animal","session","brain_region"],out_pos = True)

idx = list(indices.values())[0]
